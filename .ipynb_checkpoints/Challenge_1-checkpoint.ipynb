# %% [markdown]
# # Challenge 1

# %%
# 1. Download 20 random stocks
# 2. Calculate risk and reward potential
# 3. Compare the covariance and correlation
# 4. Find the best 5 to invest in long term

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### 1. Download 20 random stocks

# %%
tickers = [
    'DIS', 'SMCI', 'BA', 'PLTR', 'CRWD', 
    'CVNA', 'INTC', 'PLUG', 'AMC', 'PTON', 
    'DJT', 'GME', 'TSLA', 'MSTR', 'TGT', 
    'NVDA', 'FISV', 'TTD', 'LULU', 'META'
]

# %%
stocks = yf.download(tickers, start = "2022-01-01", end = "2025-12-19", auto_adjust = False)
# Out:
# [*********************100%***********************]  20 of 20 completed

# %%
stocks
# Out:
# Price        Adj Close                                                  \
# Ticker             AMC          BA        CRWD        CVNA         DIS
# Date
# 2022-01-03  265.200012  207.860001  198.330002  239.630005  153.153305
# 2022-01-04  254.899994  213.630005  189.190002  220.940002  152.147018
# 2022-01-05  227.500000  213.070007  179.289993  198.000000  151.619446
# 2022-01-06  224.600006  211.339996  187.490005  191.380005  153.290100
# 2022-01-07  229.899994  215.500000  188.990005  184.710007  154.198700
# ...                ...         ...         ...         ...         ...
# 2025-12-12    2.120000  204.380005  504.779999  455.679993  110.849998
# 2025-12-15    1.970000  205.500000  487.470001  447.920013  110.489998
# 2025-12-16    1.930000  206.710007  488.529999  455.179993  111.620003
# 2025-12-17    1.820000  206.330002  470.019989  446.230011  110.629997
# 2025-12-18    1.780000  208.270004  477.260010  465.739990  111.870003
#
# ...

# %%
stocks.to_csv("stocks_challenge1.csv")

# %%
stocks = pd.read_csv("stocks_challenge1.csv", header = [0,1], index_col = [0], parse_dates = [0])

# %%
stocks
# Out:
# Price        Adj Close                                                  \
# Ticker             AMC          BA        CRWD        CVNA         DIS
# Date
# 2022-01-03  265.200012  207.860001  198.330002  239.630005  153.153305
# 2022-01-04  254.899994  213.630005  189.190002  220.940002  152.147018
# 2022-01-05  227.500000  213.070007  179.289993  198.000000  151.619446
# 2022-01-06  224.600006  211.339996  187.490005  191.380005  153.290100
# 2022-01-07  229.899994  215.500000  188.990005  184.710007  154.198700
# ...                ...         ...         ...         ...         ...
# 2025-12-12    2.120000  204.380005  504.779999  455.679993  110.849998
# 2025-12-15    1.970000  205.500000  487.470001  447.920013  110.489998
# 2025-12-16    1.930000  206.710007  488.529999  455.179993  111.620003
# 2025-12-17    1.820000  206.330002  470.019989  446.230011  110.629997
# 2025-12-18    1.780000  208.270004  477.260010  465.739990  111.870003
#
# ...

# %%
stocks.describe()
# Out:
# Price    Adj Close                                                  \
# Ticker         AMC          BA        CRWD        CVNA         DIS
# count   995.000000  995.000000  995.000000  995.000000  995.000000
# mean     44.052844  188.405970  269.970643  129.261588  102.761355
# std      61.144251   28.881920  124.550953  120.065005   15.161203
# min       1.780000  115.860001   94.720001    3.720000   77.495041
# 25%       3.465000  169.279999  161.800003   30.125000   91.213619
# 50%       6.160000  188.619995  244.360001   83.760002  100.144638
# 75%      58.950001  210.049995  364.564987  212.269997  111.417290
# max     294.399994  264.269989  557.530029  472.730011  154.257324
#
# Price                                                               ...  \
# Ticker         DJT        FISV         GME        INTC        LULU  ...
# count   995.000000  994.000000  995.000000  995.000000  995.000000  ...
# mean     27.582558  135.853602   23.618847   31.618608  324.797638  ...
# ...

# %%
close = stocks.loc[:,"Close"]

# %%
close
# Out:
# Ticker             AMC          BA        CRWD        CVNA         DIS  \
# Date
# 2022-01-03  265.200012  207.860001  198.330002  239.630005  156.759995
# 2022-01-04  254.899994  213.630005  189.190002  220.940002  155.729996
# 2022-01-05  227.500000  213.070007  179.289993  198.000000  155.190002
# 2022-01-06  224.600006  211.339996  187.490005  191.380005  156.899994
# 2022-01-07  229.899994  215.500000  188.990005  184.710007  157.830002
# ...                ...         ...         ...         ...         ...
# 2025-12-12    2.120000  204.380005  504.779999  455.679993  111.599998
# 2025-12-15    1.970000  205.500000  487.470001  447.920013  110.489998
# 2025-12-16    1.930000  206.710007  488.529999  455.179993  111.620003
# 2025-12-17    1.820000  206.330002  470.019989  446.230011  110.629997
# 2025-12-18    1.780000  208.270004  477.260010  465.739990  111.870003
#
# Ticker            DJT        FISV        GME       INTC        LULU  \
# Date
# ...

# %% [markdown]
# ## 2. Calculate Risk and Return

# %%
#normalise data

# %%
normclose = close.div(close.iloc[0]).mul(100)

# %%
normclose
# Out:
# Ticker             AMC          BA        CRWD        CVNA         DIS  \
# Date
# 2022-01-03  100.000000  100.000000  100.000000  100.000000  100.000000
# 2022-01-04   96.116132  102.775909   95.391520   92.200475   99.342945
# 2022-01-05   85.784310  102.506498   90.399834   82.627382   98.998474
# 2022-01-06   84.690798  101.674202   94.534364   79.864792  100.089308
# 2022-01-07   86.689285  103.675551   95.290679   77.081335  100.682577
# ...                ...         ...         ...         ...         ...
# 2025-12-12    0.799397   98.325798  254.515199  190.159823   71.191632
# 2025-12-15    0.742836   98.864620  245.787323  186.921506   70.483543
# 2025-12-16    0.727753   99.446746  246.321784  189.951168   71.204393
# 2025-12-17    0.686274   99.263928  236.988849  186.216251   70.572851
# 2025-12-18    0.671192  100.197250  240.639341  194.357960   71.363873
#
# Ticker             DJT        FISV         GME        INTC        LULU  \
# Date
# ...

# %%
normclose.plot(figsize = (15,8), fontsize = 12)
plt.legend(fontsize = 12)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
ret = close.pct_change().dropna()
ret.head()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_6008\1974114209.py:1: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   ret = close.pct_change().dropna()
# Ticker           AMC        BA      CRWD      CVNA       DIS       DJT  \
# Date
# 2022-01-04 -0.038839  0.027759 -0.046085 -0.077995 -0.006571  0.010251
# 2022-01-05 -0.107493 -0.002621 -0.052328 -0.103829 -0.003467 -0.035612
# 2022-01-06 -0.012747 -0.008119  0.045736 -0.033434  0.011019  0.196546
# 2022-01-07  0.023597  0.019684  0.008000 -0.034852  0.005927 -0.104364
# 2022-01-10 -0.009134 -0.028724  0.018572 -0.006876 -0.007793  0.035754
#
# Ticker          FISV       GME      INTC      LULU      META      MSTR  \
# Date
# 2022-01-04  0.012823 -0.025713 -0.001316 -0.017391 -0.005937 -0.012879
# ...

# %%
ret.describe()
# Out:
# Ticker         AMC          BA        CRWD        CVNA         DIS  \
# count   994.000000  994.000000  994.000000  994.000000  994.000000
# mean     -0.002892    0.000277    0.001404    0.003535   -0.000158
# std       0.066141    0.023455    0.032239    0.076971    0.019054
# min      -0.419534   -0.104710   -0.147464   -0.429210   -0.131632
# 25%      -0.028812   -0.010780   -0.016111   -0.031906   -0.009262
# 50%      -0.004783    0.000447    0.002135    0.000850   -0.000245
# 75%       0.020964    0.012642    0.018722    0.030394    0.009472
# max       0.783505    0.153741    0.162965    0.560206    0.118943
#
# Ticker         DJT        FISV         GME        INTC        LULU  \
# count   994.000000  994.000000  994.000000  994.000000  994.000000
# mean      0.001031   -0.000151    0.001379    0.000100   -0.000212
# std       0.071599    0.022901    0.064362    0.031154    0.027364
# min      -0.281768   -0.440438   -0.393770   -0.260585   -0.198047
# ...

# %%
summary = ret.describe().T.loc[:,["mean","std"]]
summary
# Out:
#             mean       std
# Ticker
# AMC    -0.002892  0.066141
# BA      0.000277  0.023455
# CRWD    0.001404  0.032239
# CVNA    0.003535  0.076971
# DIS    -0.000158  0.019054
# DJT     0.001031  0.071599
# FISV   -0.000151  0.022901
# GME     0.001379  0.064362
# INTC    0.000100  0.031154
# LULU   -0.000212  0.027364
# META    0.001112  0.029253
# MSTR    0.002792  0.059106
# NVDA    0.002340  0.034046
# PLTR    0.003240  0.043340
# PLUG   -0.000687  0.061753
# PTON   -0.000186  0.056156
# SMCI    0.003428  0.056250
# TGT    -0.000566  0.023694
# TSLA    0.000950  0.039074
# TTD     0.000039  0.042618

# %%
summary["mean"] = summary["mean"] * 252
summary["std"] = summary["std"] * np.sqrt(252)
summary
# Out:
#             mean       std
# Ticker
# AMC    -0.728771  1.049963
# BA      0.069871  0.372334
# CRWD    0.353733  0.511776
# CVNA    0.890703  1.221883
# DIS    -0.039698  0.302472
# DJT     0.259834  1.136599
# FISV   -0.038145  0.363540
# GME     0.347415  1.021708
# INTC    0.025171  0.494562
# LULU   -0.053391  0.434394
# META    0.280141  0.464381
# MSTR    0.703657  0.938278
# NVDA    0.589573  0.540467
# PLTR    0.816360  0.688003
# PLUG   -0.173038  0.980303
# PTON   -0.046980  0.891441
# SMCI    0.863871  0.892943
# TGT    -0.142675  0.376132
# TSLA    0.239379  0.620288
# TTD     0.009901  0.676532

# %%
import seaborn as sns
sns.set()
summary.plot.scatter(x = "std", y = "mean", figsize = (12,8), fontsize = 15)
for i in summary.index:
    plt.annotate(i,xy = (summary.loc[i,"std"]+0.002, summary.loc[i, "mean"]+0.002),size =15)
plt.xlabel("Annual risk(std)",fontsize = 15)
plt.ylabel("Annual mean(mean)",fontsize = 15)
plt.title("Risk/return",fontsize = 25)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## Correlation and Covariance

# %%
ret
# Out:
# Ticker           AMC        BA      CRWD      CVNA       DIS       DJT  \
# Date
# 2022-01-04 -0.038839  0.027759 -0.046085 -0.077995 -0.006571  0.010251
# 2022-01-05 -0.107493 -0.002621 -0.052328 -0.103829 -0.003467 -0.035612
# 2022-01-06 -0.012747 -0.008119  0.045736 -0.033434  0.011019  0.196546
# 2022-01-07  0.023597  0.019684  0.008000 -0.034852  0.005927 -0.104364
# 2022-01-10 -0.009134 -0.028724  0.018572 -0.006876 -0.007793  0.035754
# ...              ...       ...       ...       ...       ...       ...
# 2025-12-12 -0.018519  0.018285 -0.024862 -0.036067  0.001256 -0.023831
# 2025-12-15 -0.070755  0.005480 -0.034292 -0.017029 -0.009946 -0.017840
# 2025-12-16 -0.020305  0.005888  0.002174  0.016208  0.010227  0.025813
# 2025-12-17 -0.056995 -0.001838 -0.037889 -0.019663 -0.008869 -0.024231
# 2025-12-18 -0.021978  0.009402  0.015404  0.043722  0.011209  0.419293
#
# Ticker          FISV       GME      INTC      LULU      META      MSTR  \
# Date
# ...

# %%
ret.cov()
# Out:
# Ticker       AMC        BA      CRWD      CVNA       DIS       DJT      FISV  \
# Ticker
# AMC     0.004375  0.000343  0.000505  0.001425  0.000311  0.000284  0.000150
# BA      0.000343  0.000550  0.000235  0.000547  0.000177  0.000198  0.000137
# CRWD    0.000505  0.000235  0.001039  0.001051  0.000232  0.000310  0.000169
# CVNA    0.001425  0.000547  0.001051  0.005925  0.000548  0.000581  0.000325
# DIS     0.000311  0.000177  0.000232  0.000548  0.000363  0.000287  0.000127
# DJT     0.000284  0.000198  0.000310  0.000581  0.000287  0.005126  0.000169
# FISV    0.000150  0.000137  0.000169  0.000325  0.000127  0.000169  0.000524
# GME     0.002474  0.000296  0.000515  0.001233  0.000235  0.000473  0.000142
# INTC    0.000285  0.000252  0.000356  0.000498  0.000191  0.000203  0.000145
# LULU    0.000343  0.000220  0.000313  0.000601  0.000217  0.000216  0.000175
# META    0.000324  0.000228  0.000397  0.000790  0.000219  0.000238  0.000178
# ...

# %%
ret.corr()
# Out:
# Ticker       AMC        BA      CRWD      CVNA       DIS       DJT      FISV  \
# Ticker
# AMC     1.000000  0.220780  0.236823  0.279834  0.246619  0.059895  0.099134
# BA      0.220780  1.000000  0.311233  0.302988  0.395661  0.117844  0.255301
# CRWD    0.236823  0.311233  1.000000  0.423423  0.377530  0.134333  0.228573
# CVNA    0.279834  0.302988  0.423423  1.000000  0.373548  0.105375  0.184273
# DIS     0.246619  0.395661  0.377530  0.373548  1.000000  0.210125  0.291750
# DJT     0.059895  0.117844  0.134333  0.105375  0.210125  1.000000  0.103163
# FISV    0.099134  0.255301  0.228573  0.184273  0.291750  0.103163  1.000000
# GME     0.581258  0.195818  0.247994  0.248940  0.191324  0.102710  0.096484
# INTC    0.138281  0.344694  0.354925  0.207635  0.322521  0.090911  0.203894
# LULU    0.189725  0.342685  0.354524  0.285336  0.416087  0.110420  0.279076
# META    0.167586  0.332046  0.420844  0.350890  0.393392  0.113811  0.264958
# ...

# %%
portfolio = ["PLTR", "NVDA", "SMCI", "MSTR", "CVNA"]
plt.figure(figsize=(12,8))
sns.set(font_scale = 1.4)
sns.heatmap(ret[portfolio].corr(),cmap = "Reds", annot = True, annot_kws = {"size":15},vmax = 0.6)
plt.show()
